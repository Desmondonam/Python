# %% [markdown]
# ### Import the neccesary libraries for the codes

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Import the data that we are to work with in this code

# %%
data = pd.read_csv('D:/Python/Data/Music.csv')
data.head()
# Out:
#    age  gender   genre
# 0   20       1  HipHop
# 1   23       1  HipHop
# 2   25       1  HipHop
# 3   26       1    Jazz
# 4   29       1    Jazz

# %%
data2 = pd.read_csv('D:/Python/Data/vgsales.csv')
data2.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
pd.crosstab(data2.Genre, data2.Publisher)
# Out:
# Publisher     10TACLE Studios  1C Company  20th Century Fox Video Games  \
# Genre
# Action                      0           0                             4
# Adventure                   1           0                             0
# Fighting                    0           0                             0
# Misc                        0           0                             0
# Platform                    0           0                             0
# Puzzle                      1           0                             0
# Racing                      0           1                             0
# Role-Playing                0           1                             0
# Shooter                     0           0                             1
# Simulation                  0           0                             0
# Sports                      0           0                             0
# Strategy                    1           1                             0
#
# ...
